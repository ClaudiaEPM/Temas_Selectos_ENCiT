# %% [markdown]
# # <font color="purple">**2.3 Gráficas básicas: Gráficos de línea, dispersión y barras** </font>
#
# Hasta ahora hemos aprendido a crear variables, iterarlas, operarlas e inclusive a reciclar código mediante funciones. Es decir, ya sabemos cómo generar y procesar información con Python.
# Sin embargo, **no siempre basta con solo calcular**; también **necesitamos interpretar los resultados**. Una de las formas más poderosas de hacerlo es mediante la **visualización de datos**.
#
# En Python existen diferentes librerías que permiten visualizar datos, tales como *Matplotlib*, *Seaborn*, *Cartopy*, *Plotly*, entre otros. En este curso nos enfocaremos en aprender a utilizar **Matplotlib** y **Cartopy**, las cuales constituyen herramientas fundamentales para la generación de gráficos y mapas, respectivamente. Hoy introduciremos la visualización de gráficos básicos mediante *Matplotlib* (<https://matplotlib.org/>).
#
# ------
#
# ## <font color="brown">**Matplotlib** </font>
#
# Matplotlib es una extensa biblioteca de visualización que proporciona herramientas flexibles y versátiles para la creación de gráficos 2D y 3D de alta calidad (<https://matplotlib.org/stable/plot_types/index>). Tales como:
#
# |**Gráficos básicos**|**Gráficos avanzados**|
# |--------------------|---------------------|
# |Gráficos de línea (line plots)|Histogramas de frecuencia|
# | Gráficos de dispersión (scatter plots)| Mapas de calor|
# | Gráficos de barras (bar plots)| Gráficos de bigotes|
# | Gráficos de pastel (pie charts)| Gráficas de contorno|
# ||Gráficos 3D|
#
# Matplotlib está construido sobre el paquete NumPy, por lo que trabaja de forma natural con vectores y matrices (arrays). Dentro de esta biblioteca destaca el módulo `pyplot`. Este módulo oculta muchas de las funcionalidades de bajo nivel de la biblioteca, permitiendo el uso de sencillas funciones para los elementos gráficos más habituales, tales como creación de figuras, trazado de líneas, visualización de imágenes, inserción de texto, etc.
#
# Para comenzar usando el módulo `pyplot` de *Matplotlib*, la forma estándar es importando la librería de la siguiente manera:
#
# ```python
# import matplotlib.pyplot as plt

# %%
#Importamos la librería de matplotlib
import matplotlib.pyplot as plt

#También importamos NumPy     #Como consejo: Intenten llamar todas las paqueterías que vayan a ocupar al inicio
import numpy as np

# %% [markdown]
# ### <font color="brown">¡Estamos listos para crear nuestras primeras gráficas!

# %% [markdown]
# ## <font color="darkblue"> Gráficos de línea </font>
# Son representaciones donde los puntos de datos se conectan mediante líneas para mostrar cómo una variable cambia respecto a otra. El gráfico de línea es ideal para seguir la evolución de una variable en el tiempo o frente a otra magnitud. Para este tipo de gráficos usamos la función `plt.plot`.

# %% [markdown]
# #### <font color="orange"> Ejemplo 1:

# %%
# Para hacer gráficos de línea es necesario que definan un valor para el eje x (independiente) y otro para el eje y (dependiente)

#Definimos los valores de x y y
x=np.linspace(0,10,25)
y= np.linspace(0,5,25)

#Para gráficar llamamos a la función plot
plt.plot(x,y)

# %% [markdown]
# ### <font color="brown"> Algunas instrucciones de pyplot para enchular la gráfica </font>
# (<https://matplotlib.org/stable/api/pyplot_summary.html#module-matplotlib.pyplot>)
#
# `plt.figure`: Crear objeto de figura. Usualmente sirve para especificar el tamaño que va a tener nuestro objeto de figura.
#
# `plt.show`: Muestra en pantalla la figura que han creado.
#
# `plt.xlabel`: Para establecer la etiqueta del eje x.
#
# `plt.ylabel`: Para establecer la etiqueta del eje y.
#
# `plt.title`: Para establecer el título de la gráfica.
#
# `plt.legend`: Para agregar leyendas a la gráfica.
#
# `plt.grid`: Para activar o desactivar las líneas de la cuadrícula.
#
# `plt.xlim`: Para establecer los límites del eje x.
#
# `plt.ylim`: Para establecer los límites del eje y.
#
# `plt.xticks`: Para establecer las marcas del eje x.
#
# `plt.yticks`: Para establecer las marcas del eje y.

# %% [markdown]
# #### <font color="orange"> Ejemplo 2: Variación del flujo solar durante una tormenta solar

# %%
#Valores de x
horas = np.arange(0, 24)

#Valores de y
flujo_solar = [2, 3, 4, 6, 8, 15, 30, 50, 40, 25, 18, 12,
               10, 8, 7, 6, 5, 4, 3, 3, 2, 2, 2, 2]

# %%
#Graficando 
plt.plot(horas,flujo_solar) #Recuerden que el tiempo es una variable independiente (x)

# %% [markdown]
# #### <font color="brown"> Ahora vamos a enchularla juntos

# %%
#1. Definimos nuestro objetos de figura
plt.figure(figsize=(10,5)) #anchoxalto

#2. Graficamos
plt.plot(horas,flujo_solar)

#3. Ponemos bella nuetra gráfica


#4. También podemos gardar las gráficas que creamos usando la función `plt.savefig`
# Solo tengan cuidado en dónde colocan el plt.savefig

# %% [markdown]
# #### <font color="orange"> Ejemplo 3: Múltiples líneas </font>
# Los *plots* se pueden trabajar con múltiples líneas y pueden ir integrando tantos elementos como gusten.

# %%
#Temperatura del mar (ST) a diferentes profundidades y en diferentes días

#Definimos los días de muestreo
dias = np.arange(1, 11)

#Definimos las temperaturas para cada profundidad
temp_superficie = [28, 29, 30, 29, 28, 27, 26, 27, 28, 29]
temp_50m = [24, 24, 25, 25, 24, 23, 23, 24, 24, 25]
temp_100m =[20, 20, 21, 21, 20, 19, 19, 20, 20, 21]

# %%
#Para graficar cada línea en un mismo panel, tenemos que llamar la función plot las veces que sean necesarias
plt.figure(figsize=(8,5))

plt.plot(dias,temp_superficie)
plt.plot(dias,temp_50m)
plt.plot(dias,temp_100m)

#Chuleando la gráfica
plt.title(" ST a diferentes profundidades",color="darkblue")
plt.ylabel(" ST [$^\circ$C]")
plt.xlabel("Días de muestreo")
plt.grid(linestyle="--", color="grey")

#Pero, ¿qué representa cada línea?

# Quiero que aparezcan todos los días y que se inclinen los ticks

plt.show()

# %% [markdown]
# ------
#
# #### <font color="darkblue">**Además de las funciones para enchular la gráfica, existen parámetros para embellecer las líneas. Los parámetros más comúnes son: el estilo de línea, su grosor, color y agregar marcadores.** </font>
#
# Ejemplos de parámetros en gráficos de línea:
#
# - **Linewidth** (`linewidth`): Este parámetro controla el grosor de la línea en el gráfico. Puedes especificar el grosor de la línea utilizando un valor numérico. Por ejemplo, linewidth=2 establecerá el grosor de la línea en 2 puntos.
#
# - **Color** (`color` o `c`): Este parámetro controla el color de la línea en el gráfico. Puedes especificar el color utilizando nombres de colores estándar de matplotlib (como 'blue', 'red', 'green', etc.), códigos hexadecimales ('#FF5733'), o abreviaturas de color ('b' para azul, 'r' para rojo, 'g' para verde, etc.) Para ver todos los colores, puedes consultar: <https://matplotlib.org/stable/gallery/color/named_colors.html>
#
# - **Linestyle** (`linestyle`): Este parámetro controla el estilo de la línea en el gráfico. Puedes especificar diferentes estilos de línea, como sólida ('-'), discontinua ('--'), punteada (':'), o guiones y puntos ('-.')(<https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D.set_linestyle>).
#
# - **Markers** (`marker`): Este parámetro permite agregar marcadores al gráfico de líneas. Estos nos ayudan a indicar la posición exacta de cada dato sobre la línea. Existen diferentes marcadores, como puntos ('.') , círculos ('o'), cuadrados ('s'), etc. En la siguiente liga podrán encontrar los markers posibles: <https://matplotlib.org/stable/api/markers_api.html>. Para modificar el tamaño del marker se usa el parámetro `markersize`.
#
# - **Transparencia** (`alpha`): Este parámetro controla la transparencia de los elementos del gráfico. Los valores van de 0 a 1, donde un `alpha=0` el gráfico es completamente transparente y un `alpha=1`, completamente opaco.
#
#
# **Tambíen, podemos modificar más detalles de la gráfica como el tamaño de los ejes, de las etiquetas y de los títulos.** Dentro de `plt.xlabel`, `plt.ylabel` y `plt.title` podemos modificar el tamaño de la letra con la palabra (key) `fontsize` y luego un número que es el número de puntos de la tipografía.
#
# Además, **podemos modificar la leyenda con diferentes kwargs** como `shadow`. Para ver todos los cambios posibles, ver: <https://matplotlib.org/stable/api/legend_api.html>

# %% [markdown]
# #### <font color="orange"> Ejemplo 4: Styleando

# %%
# Vamos a retomar la gráfica anterior 
plt.figure(figsize=(8,5))

plt.plot(dias,temp_superficie,label="TS",color="red")
plt.plot(dias,temp_50m,label="T_50",linewidth=2.5)
plt.plot(dias,temp_100m,label="T_100",marker="*")

#Chuleando la gráfica
plt.title(" ST a diferentes profundidades",color="darkblue")
plt.ylabel(" ST [$^\circ$C]",fontsize=15)
plt.xlabel("Días de muestreo")
plt.grid(linestyle="--", color="grey")

#Pero, ¿qué representa cada línea?
plt.legend(shadow=True)
# Quiero que aparezcan todos los días y que se inclinen los ticks
plt.xticks(np.arange(1,11,1),rotation=90)
plt.show()

# %% [markdown]
# ----
#
# ### <font color="purple"> Ejercicio 1: Funciones trigonométricas </font>
#
# Evaluén las funciones de $sen(x)$ y $cos(x)$ en el rango ($-\pi$ , $\pi$) y grafiquen su resultado en un solo panel.
# *Utiliza colores, estilos de línea y marcadores para diferenciar cada función trigonométrica. Además usa todas las funciones necesarias para mejorar tu gráfica.*

# %% [markdown]
# -------
#
# ### <font color="ForestGreen">  **Algunos otros trucos**</font>
#
# En `matplotlib.pyplot`, puedes usar la notación de *LaTeX* para renderizar fórmulas matemáticas dentro de tus gráficos utilizando el símbolo $. Esta característica es útil para agregar anotaciones, etiquetas de ejes, títulos y leyendas que contienen símbolos matemáticos y fórmulas complejas de una manera fácil y legible (<https://manualdelatex.com/simbolos>).
#
# Se puede usar la notación de LaTeX en `matplotlib.pyplot` en:
#
#     - Etiquetas de ejes y títulos: Puedes utilizar la notación de LaTeX para agregar símbolos matemáticos a las etiquetas de los ejes $x$ y $y$ y a los títulos del gráfico.
#
#     - Leyenda: también se puede agregar en la leyenda. Generalmente se usa la letra r antes del string para indicar que el string viene formateado.

# %%
#Retomando la solución del ejercicio 1
angles=np.linspace(-np.pi,np.pi,100)

sen=np.sin(angles)
cos=np.cos(angles)

plt.plot(angles, sen, linestyle="--",label=r"$sen(x)$",marker="*")
plt.plot(angles, cos, label='cos(x)')
# title define el titulo
plt.title('Funciones trigonométricas')
# xlabel define la etiqueta del eje "x"
plt.xlabel('Ángulo ($-\pi$,$\pi$)')
# ylabel define la etiqueta del eje "y"
plt.ylabel('$f (x)=sen(x)$')
# la instruccion legend agrega una leyenda
plt.legend()
# grid con lineas punteadas 
plt.grid(linestyle='--')

# %% [markdown]
# Además, `matplotlib.pyplot` proporciona varios temas predefinidos que puedes utilizar para personalizar la apariencia de tus gráficos. Puedes cambiar el tema utilizando la función `plt.style.use()`. Aquí tienes un ejemplo:

# %%
#Retomando la solución del ejercicio 1
# Cambiar al tema oscuro
plt.style.use('dark_background')

angles=np.linspace(-np.pi,np.pi,100)

sen=np.sin(angles)
cos=np.cos(angles)

plt.plot(angles, sen, linestyle="--",label=r"$sen(x)$",marker="*")
plt.plot(angles, cos, label='cos(x)')
# title define el titulo
plt.title('Funciones trigonométricas')
# xlabel define la etiqueta del eje "x"
plt.xlabel('Ángulo ($-\pi$,$\pi$)')
# ylabel define la etiqueta del eje "y"
plt.ylabel('$f (x)=sen(x)$')
# la instruccion legend agrega una leyenda
plt.legend()
# grid con lineas punteadas 
plt.grid(linestyle='--')

# %% [markdown]
# Para conocer todos los temas posibles imprime lo siguiente: `plt.style.available`.

# %% [markdown]
# ----
#
# ### <font color="brown"> Gráficos de dos ejes </font>
# Un gráfico de dos ejes permite visualizar dos variables diferentes compartiendo el mismo eje x, pero con escalas distintas en y. Es de gran utilidad cuando tenemos dos variables diferentes con unidades distintas, pero que queremos comparar en el mismo tiempo. Para ello, ocupamos la función `.twinx()`

# %% [markdown]
# #### <font color="orange"> Ejemplo: Precipitación vs Temperatura

# %%
#plt.style.use("default")
meses = np.arange(1, 13)

temperatura = [18,19,21,24,27,30,32,31,29,25,21,19]
precipitacion = [10,15,20,40,80,120,150,140,90,50,20,10]

#Creando una figura y un sistema de ejes donde se dibujará la gráfica
fig, ax1 = plt.subplots()

# Primer eje (izquierdo)
ax1.plot(meses, temperatura, color='#d7263d',label="Temperatura")

#OJO: Las funciones para poner etiquetas cambian
ax1.set_ylabel("Temperatura ($^\circ$C)", color='#d7263d')
ax1.set_xlabel("Mes")
ax1.tick_params(axis='y')

# Segundo eje (derecho)
ax2 = ax1.twinx() #Crea un nuevo eje y comparte el mismo eje x
ax2.plot(meses, precipitacion, color='#004dff',label="Precipitación")
ax2.set_ylabel("Precipitación (mm)", color='#004dff')

plt.title("Temperatura [$^\circ$C] vs Precipitación [mm]", color="brown")

#Cuidado cuando usen los grids en este tipo de gráficas
ax1.grid(linestyle="--",alpha=0.3,color="gray")
ax2.grid(linestyle="--",alpha=0.3,color="gray")

#Agregar leyenda
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.show()

# %% [markdown]
# -------
#
# ## <font color="darkblue"> Gráficos de dispersión </font>
#
# El gráfico de dispersión (scatter plot), se utilizan usualmente para comparar los valores que toman dos variables distintas. Ambas representadas en diferentes ejes. La gráfica resultante permite identificar visualmente la *posible* correlación entre ambas variables. Para hacer uso de este tipo de gráficos se usa la función `plt.scatter`.

# %% [markdown]
# #### <font color="orange">Ejemplo 1: Gráfico de puntos básico

# %%
# Generar datos
x = np.array([3, 8, 5, 6, 1, 9, 6, 7, 2, 1, 8])
y = np.array([4, 5, 2, 4, 6, 1, 4, 6, 5, 2, 3]) # Nota: Recuerden que el largo de ambas listas debe de ser igual

# Graficar
plt.figure(figsize=(5,5))
plt.scatter(x = x, y = y)
plt.grid(alpha=0.2)
plt.xlabel("Posición x")
plt.ylabel("Posición y")
plt.show()

# %% [markdown]
# ### <font color="brown"> Personalización de scatter plots </font>
#
# * **Marcador** (`marker`)
# * **Color** (`color`o `c`)
# * **Tamaño** (`s`)
# * **Contorno** (`edgecolor`)
# * **Grosor del contorno** (`linewidths`)
# * **Transparencia** (`alpha`)
#
# #### <font color="orange"> Ejemplo 2: Scatter plot personalizado

# %%
#Definimos valores randoms par x y y
np.random.seed(42)
x = np.random.randn(50)
y = np.random.randn(50)
 
plt.figure(figsize=(6, 4))
plt.scatter(x, y,
    s=100,              # tamaño del marcador
    c='steelblue',      # color
    marker='*',         # forma del marcador
    alpha=0.7,          # transparencia
    edgecolors='black', # color del borde
    linewidths=0.5,     # ancho del borde
)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de Dispersión Personalizado')
plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 3: Colormaps </font>
# También pueden usar colormaps pero para eso deben de escoger los ticks en los que irá cambiando la paleta de color y deben de ser del mismo tamaño que sus datos (<https://matplotlib.org/stable/users/explain/colors/colormaps.html>).

# %%
np.random.seed(1)

# Coordenadas simuladas (México)
latitud = np.random.uniform(14, 32, 80) #No queremos sesgo hacia ningún valor
longitud = np.random.uniform(-118, -86, 80)

# Temperatura simulada 
temperatura = np.random.randint(10,35, 80) #Misma longitud que sus datos

plt.scatter(longitud,
            latitud,  
            c=temperatura, #ticks asociados al colorbar
            cmap="inferno", #El cmap escoge una rampa de colores de acuerdo al valor dado
            marker = "o", 
            s=60, 
            alpha = 1, 
            edgecolors = "black", 
            linewidths = 1)

#Definimos la barra de color
plt.colorbar(label="Temperatura (°C)")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.title("Distribución espacial de temperatura")

plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 4: Separar por grupos de datos </font>
# No siempre vamos a plotear todo un grupo de datos, muchas veces los vamos a querer separar.

# %%
# Primera forma

#Separamos manualmente nuestros conjuntos de datos en dos o más subconjuntos
x1 = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1 = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

x2 = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y2 = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

# Plotearlos por separado
plt.scatter(x1, y1, color = 'hotpink',label="Subconjunto1")
plt.scatter(x2, y2, color = '#88c999',label="Subconjunto2")

plt.xlabel("Datos x")
plt.ylabel("Datos y")
plt.title('Primera forma')
plt.legend(fancybox=True,loc="lower left",shadow=True)
plt.show()

# %%
#Otra manera de crear leyendas

# %%
#Segunda forma
x1 = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1 = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

#Separamos los subconjuntos de datos mediante condiciones
subconjunto = np.where(x1 < 7, "yellow", "lightblue")
plt.scatter(x1, y1, color = subconjunto)

plt.title("Segunda forma")
plt.xlabel("Datos x")
plt.ylabel("Datos y")

#¿Acá cómo agregarían la leyenda?
plt.scatter([], [], color="yellow", label="x < 7")
plt.scatter([], [], color="lightblue", label="x >= 7")

plt.show()

# %% [markdown]
# ### <font color="purple">Ejercicio 2 </font>
#
# 1. Genera aleatoriamente tres conjuntos de 50 datos que representen la latitud, longitud y altitud de 50 puntos geográficos.
# 2. Crea un colormap.
# 3. Elabora un gráfico de dispersión (scatter plot) de los puntos geográficos, utilizando la latitud y longitud como coordenadas. Divide los 50 datos en dos subconjuntos y represéntalos de manera que puedan distinguirse visualmente.

# %% [markdown]
# ---------
#
# ## <font color="darkblue"> Gráficos de barras </font>
#
# Un gráfico de barras se usa para **comparar cantidades entre categorías**. Es ideal cuando tienes datos discretos, es decir, aquellos que se puedan contar. En Matplotlib ocupamos la función `.bar` para gráficos de barras.

# %% [markdown]
# ### <font color="orange"> Ejemplo 1: Alumnos por orientación </font>

# %%
#Definimos nuestros datos
estudiantes = ["Sólidos", "Atmosféricos", "Espaciales", "Acuáticos", "Ambientales"]
cantidad = np.array([3, 8, 1, 10, 3])

#Graficamos
plt.bar(estudiantes, #Categorías o posiciones
        cantidad, #Altura (valores por categoría)
        color = ['#bc6c25' , '#3a86ff', '#14213d', '#0081a7', '#a7c957'], #Colores para cada barra
        width = 0.7)#Ancho de cada barra

plt.title('Cantidad de alumnos por orientación ')
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.xlabel('Orientación')
plt.ylabel('Alumnos')
plt.show()

# %%
# Podemos cambiar la orientación de las barras, ocupando `plt.barh`

#Graficando
plt.barh(estudiantes, 
         cantidad,
         color = ['#bc6c25' , '#3a86ff', '#14213d', '#0081a7', '#a7c957'], 
         height = 0.8) # altura de las barras (valores en eje y), en pocas palabras el grosor en barras horizontales

plt.title('Cantidad de alumnos por orientación ')
plt.xlabel('Orientación')
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.ylabel('Alumnos')
plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 2: Múltiples barras por categoría </font>

# %%
#Vamos a mostrar características de diferentes especies de pingüinos (Los datos vinieron de aqui https://allisonhorst.github.io/palmerpenguins/)

#Especies de pingüinos
especie = ["Adelie", "Chinstrap", "Gentoo"]

adelite  = [18.35, 38.79 ,189.95]  #Cada lista contiene el ancho de su pico, largo del pico y largo de la la aleta
chinstrap = [18.43, 48.83, 195.82]
gentoo = [14.98, 47.50, 217.19]

#Defino el ancho de cada barra
width = 0.20

#GRAFICANDO

#Defino cuántas barras tendré por categoría
x = np.arange(3) #Asignamos un índice a cada categoría

plt.bar(x-0.2, adelite, width,color ='#d9f0ff')
plt.bar(x, chinstrap, width, color ='#a3d5ff')
plt.bar(x+0.2, gentoo, width, color ='#83c9f4')

#Definimos los nombres de las categorías de cada eje
plt.xticks(x,['Ancho Pico', 'Largo Pico', 'Largo Aleta'] )

plt.xlabel("Característica")
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.ylabel("Largo en mm")
plt.legend(especie)
plt.show()

# %% [markdown]
# **Con los mismos datos podemos hacer una representación diferente, lo importante es que sepan qué están haciendo.**

# %%
#Ahora quiero que cada categoría sea la especie y las barras sean sus características
especie = ["Adelie", "Chinstrap", "Gentoo"]


#Características
ancho_p = [18.35, 18.43, 14.98] #Adelie, Chinstrap, Gentoo
largo_p = [38.79, 48.83, 47.50] 
largo_aleta = [189.95, 195.82, 217.19]

width = 0.20

#GRAFICANDO
x = np.arange(3) 
plt.bar(x-0.2, ancho_p, width,color ='#d9f0ff',edgecolor="black") #'edcolor' color a los bordes
plt.bar(x, largo_p, width, color ='#a3d5ff',edgecolor="black")
plt.bar(x+0.2, largo_aleta, width, color ='#83c9f4',edgecolor="black")
plt.xticks(x,especie )
plt.xlabel("Característica")
plt.ylabel("Largo en mm")
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.legend(['Ancho Pico', 'Largo Pico', 'Largo Aleta'], loc = 'upper left', ncols = 3) #'ncols' nos permite definir la cantidad de columnas 
plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 3: Barras apiladas (stacked bar) </font>

# %%
#Queremos ver los días con olas de calor y olas de frío

categorias = ["México","España"]

heat_waves = [50,55]
cold_waves = [20,10]

plt.bar(categorias, heat_waves,width=0.5,label="Olas de calor",color="brown")
plt.bar(categorias, cold_waves,width=0.5,bottom=heat_waves, label="Olas de frío",color="darkblue")  #'bottom' permite apilar

plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.legend(loc="upper center")
plt.show()

# %% [markdown]
# ### <font color="purple">Ejercicio 3: Inventario de rocas </font>
#
# Imaginen que les piden generar un inventario de rocas de un laboratorio y graficar tus resultados. Para ello considera que hay rocas metamórficas, ígneas y sedimentarias. Dentro de las metarmóficas se encuentran la pizarra y el mármol; en las ígneas, basalto y el granito; en las sedimentarias, caliza y conglomerado.
#
# 1. Define la cantidad de pizarras, mármoles, basaltos, granitos, calizas y conglomerados (elige los valores que quieras).
#
# 2. Con los datos realiza un gráfico de barras en donde se represente la cantidad de rocas por cada categoría, por ejemplo para la categoría metarmófica cuántas pizarras y mármoles se encontraron y así sucesivamente (`Hint: Barras múltiples por categoría`).
#
# 3. Ahora realiza un gráfico en donde apiles la cantidad de rocas encontradas para cada categoría.
