# %% [markdown]
# # <font color="purple"> **Ejercicio 1**
# ##</font> <font color="darkblue">**Houston, tenemos un problema… de Python** </font>
#
# **¿Recuerdan el Sistema Solar?**
#
# El sistema solar es un sistema planetario constituido por una estrella que ejerce atracción gravitacional sobre los cuerpos celestes que giran a su alrededor. Entre los cuerpos que lo integran están los planetas, los cuales se pueden clasificar de las siguientes maneras: *terrestres, gigantes gaseosos, planetas helados y enanos*. Además, cada planeta posee un diámetro y distancia al sol diferente.
#
# 1. **Tu primer tarea, la cual ayudará a salvar el mundo, consiste en crear un diccionario que contenga la siguiente información:**
#
#
# |Planetas|Clasificación por tamaño y composición|Diámetro (km)| Distancia al Sol (millones de km)|
# |:------:|:-----------------:|:---:|:---:|
# |Mercurio|Terrestre|4880|58|
# |Venus|Terrestre|12104|108|
# |Tiera|Terrestre|12756|149.7|
# |Marte|Terrestre|6792|227.9|
# |Júpiter|Gaseoso|142984|778|
# |Saturno|Gaseoso|120536|1400|
# |Urano|Helado|51118|2900|
# |Neptuno|Helado|49528|4500|
# |Plutón|Enano|2400|6000|
#
#
# 2. **Crea un código que pregunte al usuario cuál es su planeta de interés y muestre en pantalla su clasificación, diámetro y distancia al Sol.**

# %% [markdown]
# # <font color="purple"> **Ejercicio 2** </font>
#
# ## <font color="darkblue"> **¿Panel solar o Turbina eólica?** </font>
#
# Vamos a evaluar la fuente de energía renovable (eólica o solar) más adecuada para cada sitio, considerando las siguientes condiciones ambientales:
#
# |   Sitio   | Radiación solar (kWh/m²/día) | Velocidad del viento (m/s) | Precipitación (mm/año) | Temperatura (°C) |
# | :-------: | :--------------------------: | :------------------------: | :--------------------: | :--------------: |
# |   Norte   |              5.8             |             7.5            |           320          |        28        |
# |   Centro  |              4.3             |             4.2            |           850          |        22        |
# |    Sur    |              6.2             |             8.3            |          1450          |        25        |
# |    Este   |              5.1             |             6.1            |           680          |        30        |
# |   Oeste   |              3.9             |             9.2            |           410          |        18        |
# | Altiplano |              6.5             |             5.4            |           290          |        16        |
#
# 1. **Crea un `DataFrame` similar a la tabla de arriba.**
# 2. **Evalúa qué tipo de energía renovable es apta para cada sitio y agrega dos nuevas columnas al DataFrame que indiquen el resultado de la evaluación para la energía solar y eólica. Para realizar la evaluación, utiliza las siguientes indicaciones:**
#   - Si la radiación solar es ≥ 5 kWh/m²/día:
#
#     - Si la precipitación es < 700 mm/año: "Solar excelente"
#     - Si la precipitación es ≥ 700 mm/año: "Solar favorable"
#
#   - Si la radiación solar es < 5:
#
#     - Si la precipitación es < 700 mm/año: "Solar moderada"
#     - Si la precipitación es ≥ 700 mm/año: "Solar poco favorable"
#
#   - Si la velocidad del viento es ≥ 7 m/s:
#
#     - Si la temperatura promedio es < 25 °C: "Eólica excelente"
#     - Si la temperatura ≥ 25 °C:"Eólica favorable"
#
#   - Si la velocidad del viento es < 7 m/s:
#
#     - Si la temperatura < 25 °C: "Eólica moderada"
#     - Si la temperatura ≥ 25 °C: "Eólica poco favorable"**

# %% [markdown]
# # <font color="purple"> **Ejercicio 3** </font>
#
# ## <font color="darkblue"> **Detectives del agua** </font>
#
# Una red de monitoreo ambiental desea simular las condiciones de diferentes cuerpos de agua antes de realizar una campaña de medición. Los valores de las variables deberán generarse aleatoriamente dentro de los siguientes rangos:
#
# | Variable                  |     Rango |
# | :-------------------------: | :--------: |
# | Temperatura del agua (°C) |   15 – 30 |
# | Oxígeno disuelto (mg/L)   |    3 – 10 |
# | pH                        | 6.5 – 8.5 |
#
# 1. **Construye un** `DataFrame` **con los datos aleatorios de las variables para 10 cuerpos de agua diferentes: 4 ríos, 3 lago y 3 lagunas.**
# 2. **Considerando que una concentración de oxígeno disuelto ≥ 7 mg/L corresponde a una condición buena, entre 5 y 7 mg/L corresponde a una condición regular y < 5 mg/L corresponde a una condición mala.**
#
#     - Clasifica cada sitio de acuerdo con su condición e incorpórala a los datos.
#     - Determina cuántos sitios pertenecen a cada categoría.

# %% [markdown]
# # <font color="purple"> **Ejercicio 4** </font>
#
# ## <font color="darkblue"> **Funciones:** </font>
#
# Crea una función que pida al usuario 2 vectores y devuelva:
#
# 1. La magnitud y ángulo de cada uno de los vectores.
# 2. La suma vectorial, la magnitud y el ángulo del vector resultante.
# 3. El producto punto.
# 4. El producto cruz.
# 5. Los vectores en coordenas polares.

# %% [markdown]
# # <font color="purple"> **Ejercicio 5** </font>
#
# ## <font color="darkblue"> **Ban-Tierra :**</font>
#
# Ahora van a crear un programa que desarroller las funciones de un banco.
# Sigue cuidadosamente las instrucciones.
#
# ### Instrucciones:
# 1. Imprime una bienvenida al banco
# 2. Crea un diccionario cuyas claves sean los nombres de al menos 3 usuarios y que tengan asociados el dinero que tienen en su cuenta.
# 3. Pide al usuario que ingrese su nombre y apellido, e imprime un saludo si son usuario (*hint*: `if nombre_completo in usuarios.keys():` ).
# 4. Crea una función que contenga el menú con las opciones: conocer tu saldo y  retirar efectivo.
# 5. Crea una función para retirar dinero y actualizar el saldo de la cuenta del usuario
# 6. Crea una función para conocer el saldo del usuario.
# 7. Usando un ciclo while, imprime el menú, pide al  usuario su respuesta, y llama a las funciones que creaste.
# 8. Convierte la información del diccionario en un `DataFrame`.
#
# ***NOTA***: Todo el código debe estar en una misma celda de ejecución para que funcione correctamente.
